# %%
import altair as alt
import os
import pandas as pd
import glob
import tensorflow as tf

# %%
summary_iterator = tf.compat.v1.train.summary_iterator

def get_section_results(file, xtag='Train_EnvstepsSoFar', ytag='Eval_AverageReturn'):
    """
        requires tensorflow==1.12.0
    """
    X = []
    Y = []
    for e in summary_iterator(file):
        for v in e.summary.value:
            if v.tag == xtag:
                X.append(v.simple_value)
            elif v.tag == ytag:
                Y.append(v.simple_value)
    return X, Y

# %%
logdir = '../../data/q2_pg_q2*/events*'
glob.glob(logdir)
# Out:
# ['../../data/q2_pg_q2_b50_r.0001_InvertedPendulum-v4_25-09-2022_23-07-29/events.out.tfevents.1664172449.mm340',
#  '../../data/q2_pg_q2_b100_r.0001_InvertedPendulum-v4_25-09-2022_23-08-09/events.out.tfevents.1664172489.mm340',
#  '../../data/q2_pg_q2_b500_r.0001_InvertedPendulum-v4_25-09-2022_23-08-51/events.out.tfevents.1664172532.mm340',
#  '../../data/q2_pg_q2_b1000_r.0001_InvertedPendulum-v4_25-09-2022_23-10-04/events.out.tfevents.1664172604.mm340',
#  '../../data/q2_pg_q2_b5000_r.0001_InvertedPendulum-v4_25-09-2022_23-11-46/events.out.tfevents.1664172706.mm340',
#  '../../data/q2_pg_q2_b50_r.001_InvertedPendulum-v4_25-09-2022_23-17-48/events.out.tfevents.1664173068.mm340',
#  '../../data/q2_pg_q2_b100_r.001_InvertedPendulum-v4_25-09-2022_23-18-28/events.out.tfevents.1664173108.mm340',
#  '../../data/q2_pg_q2_b500_r.001_InvertedPendulum-v4_25-09-2022_23-19-09/events.out.tfevents.1664173149.mm340',
#  '../../data/q2_pg_q2_b1000_r.001_InvertedPendulum-v4_25-09-2022_23-20-17/events.out.tfevents.1664173217.mm340',
#  '../../data/q2_pg_q2_b5000_r.001_InvertedPendulum-v4_25-09-2022_23-21-59/events.out.tfevents.1664173319.mm340',
#  '../../data/q2_pg_q2_b50_r.002_InvertedPendulum-v4_25-09-2022_23-27-48/events.out.tfevents.1664173668.mm340',
#  '../../data/q2_pg_q2_b100_r.002_InvertedPendulum-v4_25-09-2022_23-28-26/events.out.tfevents.1664173706.mm340',
#  '../../data/q2_pg_q2_b500_r.002_InvertedPendulum-v4_25-09-2022_23-29-11/events.out.tfevents.1664173751.mm340',
#  '../../data/q2_pg_q2_b1000_r.002_InvertedPendulum-v4_25-09-2022_23-30-17/events.out.tfevents.1664173817.mm340',
#  '../../data/q2_pg_q2_b5000_r.002_InvertedPendulum-v4_25-09-2022_23-31-56/events.out.tfevents.1664173916.mm340',
#  '../../data/q2_pg_q2_b50_r.01_InvertedPendulum-v4_25-09-2022_23-37-53/events.out.tfevents.1664174273.mm340',
#  '../../data/q2_pg_q2_b100_r.01_InvertedPendulum-v4_25-09-2022_23-38-32/events.out.tfevents.1664174312.mm340',
#  '../../data/q2_pg_q2_b500_r.01_InvertedPendulum-v4_25-09-2022_23-39-16/events.out.tfevents.1664174356.mm340',
#  '../../data/q2_pg_q2_b1000_r.01_InvertedPendulum-v4_25-09-2022_23-40-24/events.out.tfevents.1664174424.mm340',
#  '../../data/q2_pg_q2_b5000_r.01_InvertedPendulum-v4_25-09-2022_23-42-01/events.out.tfevents.1664174521.mm340',
#  '../../data/q2_pg_q2_b50_r.02_InvertedPendulum-v4_25-09-2022_23-47-40/events.out.tfevents.1664174860.mm340',
#  '../../data/q2_pg_q2_b100_r.02_InvertedPendulum-v4_25-09-2022_23-48-17/events.out.tfevents.1664174897.mm340',
#  '../../data/q2_pg_q2_b500_r.02_InvertedPendulum-v4_25-09-2022_23-48-57/events.out.tfevents.1664174937.mm340',
#  '../../data/q2_pg_q2_b1000_r.02_InvertedPendulum-v4_25-09-2022_23-50-07/events.out.tfevents.1664175007.mm340',
#  '../../data/q2_pg_q2_b5000_r.02_InvertedPendulum-v4_25-09-2022_23-51-48/events.out.tfevents.1664175108.mm340',
#  '../../data/q2_pg_q2_b50_r.1_InvertedPendulum-v4_25-09-2022_23-57-49/events.out.tfevents.1664175469.mm340',
#  '../../data/q2_pg_q2_b100_r.1_InvertedPendulum-v4_25-09-2022_23-58-30/events.out.tfevents.1664175510.mm340',
#  '../../data/q2_pg_q2_b500_r.1_InvertedPendulum-v4_25-09-2022_23-59-12/events.out.tfevents.1664175552.mm340',
#  '../../data/q2_pg_q2_b1000_r.1_InvertedPendulum-v4_26-09-2022_00-00-21/events.out.tfevents.1664175621.mm340',
#  '../../data/q2_pg_q2_b5000_r.1_InvertedPendulum-v4_26-09-2022_00-02-00/events.out.tfevents.1664175720.mm340',
#  '../../data/q2_pg_q2_b500_r.0001_InvertedPendulum-v4_29-09-2022_18-12-14/events.out.tfevents.1664500334.mm340',
#  '../../data/q2_pg_q2_b1000_r.0001_InvertedPendulum-v4_29-09-2022_18-13-17/events.out.tfevents.1664500397.mm340',
#  '../../data/q2_pg_q2_b5000_r.0001_InvertedPendulum-v4_29-09-2022_18-15-24/events.out.tfevents.1664500524.mm340',
#  '../../data/q2_pg_q2_b10000_r.0001_InvertedPendulum-v4_29-09-2022_18-39-34/events.out.tfevents.1664501974.mm340',
#  '../../data/q2_pg_q2_b500_r.001_InvertedPendulum-v4_29-09-2022_18-40-06/events.out.tfevents.1664502006.mm340',
#  '../../data/q2_pg_q2_b1000_r.001_InvertedPendulum-v4_29-09-2022_18-44-24/events.out.tfevents.1664502264.mm340',
#  '../../data/q2_pg_q2_b5000_r.001_InvertedPendulum-v4_29-09-2022_18-51-01/events.out.tfevents.1664502661.mm340',
#  '../../data/q2_pg_q2_b10000_r.001_InvertedPendulum-v4_29-09-2022_19-04-21/events.out.tfevents.1664503461.mm340',
#  '../../data/q2_pg_q2_b500_r.002_InvertedPendulum-v4_29-09-2022_19-43-53/events.out.tfevents.1664505833.mm340',
#  '../../data/q2_pg_q2_b1000_r.002_InvertedPendulum-v4_29-09-2022_19-48-12/events.out.tfevents.1664506092.mm340',
#  '../../data/q2_pg_q2_b5000_r.002_InvertedPendulum-v4_29-09-2022_19-52-42/events.out.tfevents.1664506362.mm340',
#  '../../data/q2_pg_q2_b10000_r.002_InvertedPendulum-v4_29-09-2022_19-58-10/events.out.tfevents.1664506690.mm340',
#  '../../data/q2_pg_q2_b500_r.01_InvertedPendulum-v4_29-09-2022_20-08-12/events.out.tfevents.1664507292.mm340',
#  '../../data/q2_pg_q2_b1000_r.01_InvertedPendulum-v4_29-09-2022_20-09-13/events.out.tfevents.1664507353.mm340',
#  '../../data/q2_pg_q2_b5000_r.01_InvertedPendulum-v4_29-09-2022_20-10-44/events.out.tfevents.1664507444.mm340',
#  '../../data/q2_pg_q2_b10000_r.01_InvertedPendulum-v4_29-09-2022_20-16-05/events.out.tfevents.1664507765.mm340',
#  '../../data/q2_pg_q2_b500_r.02_InvertedPendulum-v4_29-09-2022_20-26-28/events.out.tfevents.1664508388.mm340',
#  '../../data/q2_pg_q2_b1000_r.02_InvertedPendulum-v4_29-09-2022_20-27-35/events.out.tfevents.1664508455.mm340',
#  '../../data/q2_pg_q2_b5000_r.02_InvertedPendulum-v4_29-09-2022_20-29-10/events.out.tfevents.1664508550.mm340',
#  '../../data/q2_pg_q2_b10000_r.02_InvertedPendulum-v4_29-09-2022_20-34-32/events.out.tfevents.1664508872.mm340',
#  '../../data/q2_pg_q2_b500_r.1_InvertedPendulum-v4_29-09-2022_20-44-48/events.out.tfevents.1664509488.mm340',
#  '../../data/q2_pg_q2_b1000_r.1_InvertedPendulum-v4_29-09-2022_20-45-50/events.out.tfevents.1664509550.mm340',
#  '../../data/q2_pg_q2_b5000_r.1_InvertedPendulum-v4_29-09-2022_20-47-21/events.out.tfevents.1664509641.mm340',
#  '../../data/q2_pg_q2_b10000_r.1_InvertedPendulum-v4_29-09-2022_20-52-57/events.out.tfevents.1664509977.mm340',
#  '../../data/q2_pg_q2_b1000_r.01_InvertedPendulum-v4_29-09-2022_22-47-41/events.out.tfevents.1664516861.mm340',
#  '../../data/q2_pg_q2_b3000_r.01_InvertedPendulum-v4_29-09-2022_22-51-24/events.out.tfevents.1664517084.mm340',
#  '../../data/q2_pg_q2_b1000_r.01_InvertedPendulum-v4_29-09-2022_22-51-38/events.out.tfevents.1664517098.mm340',
#  '../../data/q2_pg_q2_b3000_r.01_InvertedPendulum-v4_29-09-2022_22-53-17/events.out.tfevents.1664517197.mm340',
#  '../../data/q2_pg_q2_b1000_r.01_InvertedPendulum-v4_29-09-2022_22-56-38/events.out.tfevents.1664517398.mm340',
#  '../../data/q2_pg_q2_b3000_r.01_InvertedPendulum-v4_29-09-2022_22-58-12/events.out.tfevents.1664517492.mm340',
#  '../../data/q2_pg_q2_b5000_r.01_InvertedPendulum-v4_29-09-2022_23-02-04/events.out.tfevents.1664517724.mm340',
#  '../../data/q2_pg_q2_b1000_r.008_InvertedPendulum-v4_29-09-2022_23-07-31/events.out.tfevents.1664518051.mm340',
#  '../../data/q2_pg_q2_b3000_r.008_InvertedPendulum-v4_29-09-2022_23-09-06/events.out.tfevents.1664518146.mm340',
#  '../../data/q2_pg_q2_b5000_r.008_InvertedPendulum-v4_29-09-2022_23-12-47/events.out.tfevents.1664518367.mm340',
#  '../../data/q2_pg_q2_b1000_r.01_InvertedPendulum-v4_29-09-2022_23-18-49/events.out.tfevents.1664518729.mm340',
#  '../../data/q2_pg_q2_b3000_r.01_InvertedPendulum-v4_29-09-2022_23-22-02/events.out.tfevents.1664518922.mm340']

# %%
def make_dataframe(eventfiles, xtag='Train_EnvstepsSoFar', ytag='Eval_AverageReturn'):
    dfs = []
    for eventfile in eventfiles:
        dirname = os.path.basename(os.path.dirname(eventfile))
        X, Y = get_section_results(eventfile, xtag, ytag)
        n = len(X)
        assert len(X) == len(Y)
        log_df = pd.DataFrame.from_dict({xtag: X, ytag: Y, 'exp': [dirname] * n})
        dfs.append(log_df)
    
    return pd.concat(dfs)

# %% [markdown]
# # Q1

# %%
logdir = '../../data/q2_pg_q1_sb*/events*'
eventfiles = glob.glob(logdir)
xtag = 'Train_EnvstepsSoFar'
ytag = 'Eval_AverageReturn'
df_q1  = make_dataframe(eventfiles, xtag=xtag, ytag=ytag)

chart = alt.Chart(df_q1).mark_line().encode(
    x=xtag,
    y=ytag,
    color='exp'
)
chart = chart.configure_legend(
    labelLimit=1000
)
chart
# Out:
# alt.Chart(...)

# %%
logdir = '../../data/q2_pg_q1_lb*/events*'
eventfiles = glob.glob(logdir)
xtag = 'Train_EnvstepsSoFar'
ytag = 'Eval_AverageReturn'
df_q1  = make_dataframe(eventfiles, xtag=xtag, ytag=ytag)

chart = alt.Chart(df_q1).mark_line().encode(
    x=xtag,
    y=ytag,
    color='exp'
)
chart = chart.configure_legend(
    labelLimit=1000
)
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# # Q2

# %%
alt.data_transformers.disable_max_rows()

logdir = '../../data/q2_pg_q2*/events*'
eventfiles = glob.glob(logdir)
xtag = 'Train_EnvstepsSoFar'
ytag = 'Eval_AverageReturn'
df_q2  = make_dataframe(eventfiles, xtag=xtag, ytag=ytag)

chart = alt.Chart(df_q2).mark_line().encode(
    x=xtag,
    y=ytag,
    color='exp'
)
chart = chart.configure_legend(
    labelLimit=1000
)
chart
# Out:
# alt.Chart(...)

# %%
df_q2[df_q2['Eval_AverageReturn'] >= 900]
# Out:
#     Train_EnvstepsSoFar  Eval_AverageReturn  \
# 72               9070.0               910.0
# 42              45602.0              1000.0
# 78             400264.0               953.0
# 79             406225.0              1000.0
# 80             411225.0              1000.0
# 81             416225.0              1000.0
# 42              45602.0              1000.0
# 78             400264.0               953.0
# 79             406225.0              1000.0
# 80             411225.0              1000.0
# 81             416225.0              1000.0
#
#                                                   exp
# 72  q2_pg_q2_b100_r.01_InvertedPendulum-v4_25-09-2...
# 42  q2_pg_q2_b1000_r.02_InvertedPendulum-v4_25-09-...
# 78  q2_pg_q2_b5000_r.02_InvertedPendulum-v4_25-09-...
# 79  q2_pg_q2_b5000_r.02_InvertedPendulum-v4_25-09-...
# 80  q2_pg_q2_b5000_r.02_InvertedPendulum-v4_25-09-...
# 81  q2_pg_q2_b5000_r.02_InvertedPendulum-v4_25-09-...
# 42  q2_pg_q2_b1000_r.02_InvertedPendulum-v4_29-09-...
# 78  q2_pg_q2_b5000_r.02_InvertedPendulum-v4_29-09-...
# 79  q2_pg_q2_b5000_r.02_InvertedPendulum-v4_29-09-...
# 80  q2_pg_q2_b5000_r.02_InvertedPendulum-v4_29-09-...
# 81  q2_pg_q2_b5000_r.02_InvertedPendulum-v4_29-09-...

# %% [markdown]
# # Q3

# %%
alt.data_transformers.disable_max_rows()

logdir = '../../data/q2_pg_q3*/events*'
eventfiles = glob.glob(logdir)
xtag = 'Train_EnvstepsSoFar'
ytag = 'Eval_AverageReturn'
df_q2  = make_dataframe(eventfiles, xtag=xtag, ytag=ytag)

chart = alt.Chart(df_q2).mark_line().encode(
    x=xtag,
    y=ytag,
    color='exp'
)
chart = chart.configure_legend(
    labelLimit=1000
)
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# # Q4

# %%
alt.data_transformers.disable_max_rows()

logdir = '../../data/q2_pg_q4_search*/events*'
eventfiles = glob.glob(logdir)
xtag = 'Train_EnvstepsSoFar'
ytag = 'Eval_AverageReturn'
df_q2  = make_dataframe(eventfiles, xtag=xtag, ytag=ytag)

chart = alt.Chart(df_q2).mark_line().encode(
    x=xtag,
    y=ytag,
    color='exp'
)
chart = chart.configure_legend(
    labelLimit=1000
)
chart
# Out:
# alt.Chart(...)

# %%
alt.data_transformers.disable_max_rows()

logdir = '../../data/q2_pg_q4_b*/events*'
eventfiles = glob.glob(logdir)
xtag = 'Train_EnvstepsSoFar'
ytag = 'Eval_AverageReturn'
df_q2  = make_dataframe(eventfiles, xtag=xtag, ytag=ytag)

chart = alt.Chart(df_q2).mark_line().encode(
    x=xtag,
    y=ytag,
    color='exp'
)
chart = chart.configure_legend(
    labelLimit=1000
)
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# # Q5

# %%
alt.data_transformers.disable_max_rows()

logdir = '../../data/q2_pg_q5*/events*'
eventfiles = glob.glob(logdir)
xtag = 'Train_EnvstepsSoFar'
ytag = 'Eval_AverageReturn'
df_q2  = make_dataframe(eventfiles, xtag=xtag, ytag=ytag)

chart = alt.Chart(df_q2).mark_line().encode(
    x=xtag,
    y=ytag,
    color='exp'
)
chart = chart.configure_legend(
    labelLimit=1000
)
chart
# Out:
# alt.Chart(...)
